# %%
from data_prep import DataPrep
from dimension_redux import DimensionRedux

import pandas as pd
import numpy as np

# %%
# ML Project Framework 
# 1. Data Integration, Pipelining
# 2. Dimensionality reduction
# 3. Classifier, Regressor (Use Sector Differentiation if possible)
# 4. Predict Return / Return class
# 5. Use Prediction to backtest simple strategy (fee, signal construction)
# 6. Model Eval

# %%
dr_obj = DimensionRedux()
dr_obj.data_initialization(return_df=True)
dr_obj.data_construction(return_df=True)
# Out:
# data initialized
# DataFrame size: (4135225, 135)
# data construction complete
# DataFrame size: (987322, 128)
#              date     id ticker                  sector size_grp       prc  \
# 1685     19860131  10009   IROQ                 Finance     nano -0.282568
# 1686     19860228  10009   IROQ                 Finance     nano -0.253850
# 1687     19860331  10009   IROQ                 Finance     nano -0.244781
# 1688     19860430  10009   IROQ                 Finance     nano -0.270476
# 1689     19860530  10009   IROQ                 Finance     nano -0.277278
# ...           ...    ...    ...                     ...      ...       ...
# 3928474  20220831  93436   TSLA  Consumer Discretionary     mega  2.904992
# 3928475  20220930  93436   TSLA  Consumer Discretionary     mega  2.779720
# 3928476  20221031  93436   TSLA  Consumer Discretionary     mega  2.323732
# 3928477  20221130  93436   TSLA  Consumer Discretionary     mega  1.926632
# ...

# %%
# PCA
pca_reduced_df = dr_obj.pca_fit()
# Out:
# DataFrame size: (383078, 128)

# %%
pca_reduced_df['ret_class'].unique()
# Out:
# array([3, 2, 1])

# %%
# LDA 
lda_reduced_df = dr_obj.lda_fit()
# Out:
# DataFrame size: (383078, 128)
# /Users/pengjin/Desktop/ml_project/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# /Users/pengjin/Desktop/ml_project/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# /Users/pengjin/Desktop/ml_project/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# Mean Accuracy: 0.531 (0.003)

# %%
# SVD 
svd_reduced_df = dr_obj.svd_fit()
# Out:
# DataFrame size: (383078, 128)

# %%
# FA 
fa_reduced_df = dr_obj.fa_fit()
# Out:
# DataFrame size: (383078, 128)
