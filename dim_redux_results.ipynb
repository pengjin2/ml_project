# %%
from data_prep import DataPrep
from dimension_redux import DimensionRedux

import pandas as pd
import numpy as np

# %%
# ML Project Framework 
# 1. Data Integration, Pipelining
# 2. Dimensionality reduction
# 3. Classifier, Regressor (Use Sector Differentiation if possible)
# 4. Predict Return / Return class
# 5. Use Prediction to backtest simple strategy (fee, signal construction)
# 6. Model Eval

# %%
dr_obj = DimensionRedux()
dr_obj.data_initialization()
dr_obj.data_construction()
# Out:
# data initialized
# /Users/pengjin/Desktop/ml_project/data_prep.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stock_data['ret_exc_lead1m_std'] = pd.DataFrame(scaler.fit_transform(self.stock_data[['ret_exc_lead1m']]))
# data construction complete

# %%
# PCA
pca_reduced_df = dr_obj.pca_fit()
# Out:
# DataFrame size: (49582, 138)

# %%
pca_reduced_df
# Out:
#         index      date     id ticker            sector size_grp  index  \
# 0        4635  19890228  10026   JJSF  Consumer Staples    micro      0
# 1        4637  19890428  10026   JJSF  Consumer Staples    micro      1
# 2        4638  19890531  10026   JJSF  Consumer Staples    micro      2
# 3        4639  19890630  10026   JJSF  Consumer Staples    small      3
# 4        4640  19890731  10026   JJSF  Consumer Staples    small      4
# ...       ...       ...    ...    ...               ...      ...    ...
# 49577  986213  20220531  21371    CAH       Health Care     mega  49577
# 49578  986214  20220630  21371    CAH       Health Care     mega  49578
# 49579  986215  20220729  21371    CAH       Health Care     mega  49579
# 49580  986216  20220831  21371    CAH       Health Care     mega  49580
# 49581  986217  20220930  21371    CAH       Health Care     mega  49581
#
#          comp_0    comp_1    comp_2  ...    comp_5    comp_6    comp_7  \
# 0     -1.256597 -0.102245 -0.065891  ...  1.694260 -1.661469 -1.297101
# 1     -1.267718 -0.108541 -0.076502  ...  0.928536 -1.501271 -1.557814
# 2     -1.273503 -0.100418 -0.079949  ...  1.844791 -1.560573 -1.095018
# 3     -1.311026 -0.110792 -0.099821  ...  0.994913 -1.511234 -1.080145
# 4     -1.223204 -0.105477 -0.061369  ...  1.454094 -1.870484 -2.083565
# ...         ...       ...       ...  ...       ...       ...       ...
# 49577 -0.231950 -0.052208 -0.045127  ...  0.037022  0.863027 -0.009069
# 49578 -0.302552 -0.056551 -0.013831  ... -0.375681  1.005480 -0.770628
# 49579 -0.169293 -0.050126 -0.019621  ... -0.360288  1.128308 -0.835354
# 49580 -0.097952 -0.044758 -0.028096  ...  0.719400  0.916515  0.214183
# 49581 -0.083436 -0.039050 -0.050118  ...  1.515907  0.848057  0.656085
#
#          comp_8    comp_9   comp_10   index  ret_exc_lead1m  \
# 0     -0.426803 -0.314704  0.636470    4635        0.038731
# 1     -1.209659  0.628171  0.570900    4637        0.068917
# 2     -1.228698  0.996834 -0.276232    4638        0.055353
# 3     -0.826205  1.860250 -0.504180    4639        0.127414
# 4     -1.610120  0.538791  0.873436    4640       -0.073351
# ...         ...       ...       ...     ...             ...
# 49577  0.256226 -1.551887  2.097589  986213       -0.063676
# 49578  0.143080 -1.922771  2.177653  986214        0.138656
# 49579  0.180742 -1.598493  1.909062  986215        0.185473
# 49580  0.455257 -0.855426  2.061239  986216       -0.052046
# 49581 -0.050399 -1.230180  2.003354  986217        0.135945
#
#        ret_exc_lead1m_std  ret_class
# 0                0.562041          4
# 1               -0.105094          5
# 2               -0.444136          4
# 3                0.813956          5
# 4               -0.451736          2
# ...                   ...        ...
# 49577           -0.065985          2
# 49578           -0.214936          5
# 49579            0.211615          5
# 49580           -0.287228          2
# 49581            0.672159          5
#
# [49582 rows x 22 columns]

# %%
# LDA 
lda_reduced_df = dr_obj.lda_fit()
# Out:
# DataFrame size: (49582, 138)
# /Users/pengjin/Desktop/ml_project/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# /Users/pengjin/Desktop/ml_project/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# /Users/pengjin/Desktop/ml_project/.venv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# Mean Accuracy: 0.328 (0.005)

# %%
# SVD 
svd_reduced_df = dr_obj.svd_fit()
# Out:
# DataFrame size: (49582, 138)

# %%
# FA 
fa_reduced_df = dr_obj.fa_fit()
# Out:
# DataFrame size: (49582, 138)
